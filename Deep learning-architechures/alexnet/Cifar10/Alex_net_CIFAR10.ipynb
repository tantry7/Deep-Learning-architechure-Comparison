# %% [markdown]
# AlexNet consists of 5 Convolutional Layers and 3 Fully Connected Layers. In Convolutional Neural Networks, Filters detect spatial patterns such as edges in an image by detecting the changes in intensity values of the image. valid" means no padding. "same" results in padding with zeros

# %%
import numpy as np
import numpy as np
import os
from keras.datasets import cifar10, cifar100
from keras.models import Sequential
from keras.layers import Dense, Conv2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping
from keras.regularizers import l2
from keras import backend as K
import pandas as pd
from keras.utils import np_utils
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline
import skimage
from skimage.util import img_as_ubyte

# %%
DATASET = 'cifar-10'
input_shape=(32,32,3)
num_classes = 10
model_type = 'Alexnet'
epochs = 50
lrate = 0.01
decay = lrate/epochs
batch_size = 32
data_augmentation = False
flow_from_dir = False
subtract_mean = True
seed = 7
np.random.seed(seed)

validate_dir = os.path.join("data","test")
train_dir = os.path.join("data","train")
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = DATASET+'_'+'%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print("Model Type: ",model_type)
print("Model File: ",filepath)
# Out:
# Model Type:  Alexnet
# Model File:  /content/saved_models/cifar-10_Alexnet_model.{epoch:03d}.h5

# %%
if flow_from_dir:
  if DATASET == 'cifar-10':
    # %pip install cifar2png
    # %cifar2png cifar10 "data"

# %%
if not flow_from_dir:
  #load data
  if DATASET == 'cifar-10':
    (X_train, y_train),(X_test,y_test) = cifar10.load_data()
    X_train.shape, X_test.shape, X_train.shape[1:],X_train.dtype
  elif DATASET == 'cifar-100':
    (X_train, y_train),(X_test,y_test) = cifar100.load_data()
    X_train.shape, X_test.shape, X_train.shape[1:],X_train.dtype

  for i in range(0,9):
    plt.subplot(330+1+i)
    plt.imshow(X_train[i])
  plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step

# %%
def convert_to_imagenet_size(images):
  tmp_images = []
  for image in images:
    image = skimage.transform.resize(image,(224,224),mode='constant')
    image = img_as_ubyte(image)
    tmp_images.append(image)
  return np.array(tmp_images)

# %%
#Data Normalization
if not flow_from_dir:
  if not data_augmentation:
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    X_train = X_train/255.
    X_test = X_test/255.

    if subtract_mean:
      X_train_mean = np.mean(X_train)
      X_train -= X_train_mean
      X_test_mean = np.mean(X_test)
      X_test -= X_test_mean

  print(y_train.shape, y_test.shape)
# Out:
# (50000, 1) (10000, 1)

# %%
if not flow_from_dir:
  y_train = np_utils.to_categorical(y_train)
  y_test = np_utils.to_categorical(y_test)
  print(y_train.shape, y_test.shape)
# Out:
# (50000, 10) (10000, 10)

# %%
input_shape,num_classes
# Out:
# ((32, 32, 3), 10)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler,early_stopping]

# %%
def AlexnetModel(input_shape,num_classes):
  model = Sequential()
  model.add(Conv2D(filters=96,kernel_size=(3,3),strides=(4,4),input_shape=input_shape, activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
  model.add(Conv2D(256,(5,5),padding='same',activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
  model.add(Conv2D(384,(3,3),padding='same',activation='relu'))
  model.add(Conv2D(384,(3,3),padding='same',activation='relu'))
  model.add(Conv2D(256,(3,3),padding='same',activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

  model.add(Flatten())
  model.add(Dense(4096, activation='relu'))
  model.add(Dropout(0.4))
  model.add(Dense(4096, activation='relu'))
  model.add(Dropout(0.4))
  model.add(Dense(num_classes,activation='softmax'))
  return model

# %%
import tensorflow

# %%
model = AlexnetModel(input_shape,num_classes)
optimizer = tensorflow.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss= 'categorical_crossentropy' , optimizer=optimizer, metrics=[ 'accuracy' ])
print("Model Summary of ",model_type)
print(model.summary())
# Out:
# Model Summary of  Alexnet
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 8, 8, 96)          2688
#
#  max_pooling2d_6 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 256)         614656
#
#  max_pooling2d_7 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 2, 2, 384)         885120
#
#  conv2d_13 (Conv2D)          (None, 2, 2, 384)         1327488
#
#  conv2d_14 (Conv2D)          (None, 2, 2, 256)         884992
#
#  max_pooling2d_8 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 4096)              1052672
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  dense_7 (Dense)             (None, 4096)              16781312
#
#  dropout_5 (Dropout)         (None, 4096)              0
#
#  dense_8 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 21,589,898
# Trainable params: 21,589,898
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
import time
start = time.time()
if data_augmentation:
	print('Using real-time data augmentation.')
	# This will do preprocessing and realtime data augmentation:
	datagen = ImageDataGenerator(
        featurewise_center=True,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=True,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=20,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.2,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.2,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).


if not flow_from_dir:
	if not data_augmentation:
		print('Not using data augmentation.')
		history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(X_test, y_test),
          shuffle=True
          )
	else:   
		print("model using data from downloaded dataset in memoory")
		datagen.fit(X_train)
		# Fit the model on the batches generated by datagen.flow().
		history = model.fit_generator(datagen.flow(X_train, y_train,
                                 batch_size=batch_size),
                                 epochs=epochs,
                                 validation_data=datagen.flow((X_test, y_test),batch_size=batch_size),
                                 workers=4
                                 )
  
	scores = model.evaluate(X_test, y_test, verbose=1)

else:
	# generator for reading train data from folder

	print('Model fit using flow from directory')


	train_generator = datagen.flow_from_directory(
      train_dir,
      target_size = (224, 224),
      color_mode = 'rgb',
      batch_size = batch_size,
      class_mode = 'categorical',
      shuffle=False,
      seed=42
      )
	#
	# generator for reading validation data from folder

	validation_generator = datagen.flow_from_directory(
      validate_dir,
      target_size = (224, 224),
      color_mode = 'rgb',
      batch_size = batch_size,
      class_mode = 'categorical',
      shuffle=False,
      seed=42)
  
	STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
	STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size
  
	history = model.fit_generator(generator=train_generator,
                steps_per_epoch=STEP_SIZE_TRAIN,
                validation_data=validation_generator,
                validation_steps=STEP_SIZE_VALID,
                epochs=10,
                callbacks=callbacks
                )
  
	scores = model.evaluate_generator(generator=validation_generator,
                           steps=STEP_SIZE_VALID, verbose=1)

	#Predict the output
	''' Use when to Predict the output
	STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
	test_generator.reset()
	pred=model.predict_generator(test_generator,
                               steps=STEP_SIZE_TEST,
                               verbose=1)

	'''
# Save model and weights



# Score trained model.
end = time.time()
print(f"Time elapsed: {end-start}")
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Not using data augmentation.
# Epoch 1/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.0932 - accuracy: 0.6141 - val_loss: 1.1913 - val_accuracy: 0.5773
# Epoch 2/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.0173 - accuracy: 0.6450 - val_loss: 1.1702 - val_accuracy: 0.5926
# Epoch 3/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9483 - accuracy: 0.6702 - val_loss: 1.1533 - val_accuracy: 0.6053
# Epoch 4/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8895 - accuracy: 0.6921 - val_loss: 1.1378 - val_accuracy: 0.6078
# Epoch 5/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8292 - accuracy: 0.7137 - val_loss: 1.2329 - val_accuracy: 0.6111
# Epoch 6/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7731 - accuracy: 0.7321 - val_loss: 1.2539 - val_accuracy: 0.6156
# Epoch 7/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7255 - accuracy: 0.7503 - val_loss: 1.2340 - val_accuracy: 0.6097
# Epoch 8/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6717 - accuracy: 0.7722 - val_loss: 1.2785 - val_accuracy: 0.6114
# Epoch 9/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6372 - accuracy: 0.7843 - val_loss: 1.3259 - val_accuracy: 0.6108
# Epoch 10/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5932 - accuracy: 0.7998 - val_loss: 1.3823 - val_accuracy: 0.6152
# Epoch 11/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5426 - accuracy: 0.8168 - val_loss: 1.5007 - val_accuracy: 0.5967
# Epoch 12/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5203 - accuracy: 0.8270 - val_loss: 1.5605 - val_accuracy: 0.6056
# Epoch 13/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.4801 - accuracy: 0.8390 - val_loss: 1.5472 - val_accuracy: 0.6057
# Epoch 14/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.4722 - accuracy: 0.8440 - val_loss: 1.5199 - val_accuracy: 0.5961
# Epoch 15/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.4328 - accuracy: 0.8573 - val_loss: 1.7633 - val_accuracy: 0.6035
# Epoch 16/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.4103 - accuracy: 0.8654 - val_loss: 1.7787 - val_accuracy: 0.6021
# Epoch 17/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.4418 - accuracy: 0.8566 - val_loss: 1.7598 - val_accuracy: 0.6090
# Epoch 18/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3646 - accuracy: 0.8831 - val_loss: 1.8189 - val_accuracy: 0.6039
# Epoch 19/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3512 - accuracy: 0.8872 - val_loss: 1.8791 - val_accuracy: 0.5852
# Epoch 20/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3352 - accuracy: 0.8924 - val_loss: 1.9152 - val_accuracy: 0.6023
# Epoch 21/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3197 - accuracy: 0.8974 - val_loss: 1.9538 - val_accuracy: 0.6041
# Epoch 22/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3143 - accuracy: 0.9006 - val_loss: 1.9995 - val_accuracy: 0.5994
# Epoch 23/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3069 - accuracy: 0.9066 - val_loss: 1.9829 - val_accuracy: 0.6065
# Epoch 24/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3233 - accuracy: 0.9004 - val_loss: 1.9243 - val_accuracy: 0.6086
# Epoch 25/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2789 - accuracy: 0.9131 - val_loss: 2.3136 - val_accuracy: 0.5985
# Epoch 26/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2849 - accuracy: 0.9144 - val_loss: 2.2683 - val_accuracy: 0.6023
# Epoch 27/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2610 - accuracy: 0.9217 - val_loss: 1.9427 - val_accuracy: 0.6029
# Epoch 28/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2407 - accuracy: 0.9261 - val_loss: 2.0208 - val_accuracy: 0.5968
# Epoch 29/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2509 - accuracy: 0.9245 - val_loss: 2.1242 - val_accuracy: 0.6082
# Epoch 30/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2306 - accuracy: 0.9313 - val_loss: 2.0829 - val_accuracy: 0.5967
# Epoch 31/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2919 - accuracy: 0.9181 - val_loss: 2.0737 - val_accuracy: 0.6057
# Epoch 32/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2150 - accuracy: 0.9369 - val_loss: 2.3671 - val_accuracy: 0.6040
# Epoch 33/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2151 - accuracy: 0.9355 - val_loss: 2.6652 - val_accuracy: 0.5991
# Epoch 34/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2160 - accuracy: 0.9363 - val_loss: 2.7044 - val_accuracy: 0.5945
# Epoch 35/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2223 - accuracy: 0.9357 - val_loss: 2.4670 - val_accuracy: 0.5932
# Epoch 36/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2210 - accuracy: 0.9386 - val_loss: 2.3393 - val_accuracy: 0.6009
# Epoch 37/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1887 - accuracy: 0.9461 - val_loss: 2.3667 - val_accuracy: 0.6017
# Epoch 38/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2084 - accuracy: 0.9416 - val_loss: 2.2071 - val_accuracy: 0.5933
# Epoch 39/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1945 - accuracy: 0.9434 - val_loss: 2.2592 - val_accuracy: 0.6019
# Epoch 40/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2681 - accuracy: 0.9244 - val_loss: 2.0767 - val_accuracy: 0.5997
# Epoch 41/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1764 - accuracy: 0.9501 - val_loss: 2.0772 - val_accuracy: 0.6044
# Epoch 42/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1847 - accuracy: 0.9487 - val_loss: 2.4311 - val_accuracy: 0.6006
# Epoch 43/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2050 - accuracy: 0.9422 - val_loss: 2.3673 - val_accuracy: 0.6042
# Epoch 44/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2176 - accuracy: 0.9388 - val_loss: 2.6641 - val_accuracy: 0.6038
# Epoch 45/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1696 - accuracy: 0.9534 - val_loss: 2.3206 - val_accuracy: 0.6064
# Epoch 46/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1789 - accuracy: 0.9503 - val_loss: 2.2684 - val_accuracy: 0.6016
# Epoch 47/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1722 - accuracy: 0.9535 - val_loss: 2.5060 - val_accuracy: 0.5995
# Epoch 48/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1730 - accuracy: 0.9534 - val_loss: 2.1833 - val_accuracy: 0.6020
# Epoch 49/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1702 - accuracy: 0.9539 - val_loss: 2.5154 - val_accuracy: 0.6023
# Epoch 50/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2451 - accuracy: 0.9321 - val_loss: 2.8406 - val_accuracy: 0.6033
# 313/313 [==============================] - 1s 4ms/step - loss: 2.8406 - accuracy: 0.6033
# Time elapsed: 709.1091051101685
# Test loss: 2.8406221866607666
# Test accuracy: 0.6032999753952026

# %%
# list all data in history
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
